# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from PIL import Image

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)  # Show full column names

# %%
df = pd.read_excel('Questionnaire_on_Hostel_Preferences_Among_Undergraduate_Students_at_KNUST_-_all_versions_-_labels_-_2.xlsx')
display(df)
# Out:
#                       start                     end  Gender  Year of Study  \
# 0   2025-07-16 09:53:13.995 2025-07-16 09:57:40.138    Male              4
# 1   2025-07-16 22:00:56.969 2025-07-16 22:06:20.825    Male              4
# 2   2025-07-17 10:31:54.822 2025-07-17 10:46:25.056  Female              4
# 3   2025-07-17 10:29:39.390 2025-07-17 10:48:24.244    Male              4
# 4   2025-07-17 10:46:25.084 2025-07-17 10:52:05.288  Female              4
# ..                      ...                     ...     ...            ...
# 395 2025-07-29 19:39:08.545 2025-07-29 19:45:19.420  Female              1
# 396 2025-07-29 19:41:40.027 2025-07-29 19:47:16.656    Male              2
# 397 2025-07-29 15:58:30.005 2025-07-29 20:01:32.909    Male              2
# 398 2025-07-29 19:57:24.173 2025-07-29 20:04:13.915    Male              4
# 399 2025-07-29 19:43:17.264 2025-07-29 20:05:18.221    Male              2
#
#     Where are you currently staying?  \
# ...

# %%
## GPT helped to scale it to the actual unique hostels from this code: list(df['If you stay in a hostel, what is the name of your hostel?'].unique())

unique_hostels = [
 'Adombi',
 'Adowa Ekyaa Hostel',
 'Afirim Hostel',
 'Agape Chara',
 'Anglican Hostel',
 'Anarosa',
 'Baby Brunei',
 'Banant',
 'Bible College Hostel',
 'Brunei Complex',
 'By His Grace',
 'Canam Hostel',
 'Canam Premium',
 'Carsars Palace',
 'Cedar Residence',
 'Celia Royale Hostel',
 'Chancellor (Hall 7)',
 'Chancellors Hall',
 'Complex',
 'Crystal Rose Hostel',
 'Devalypa Hostel',
 'Dorchester Hostel',
 'Dr Sarfo Hostel',
 'Ebenezer Hostel',
 'Esperstar Apartments',
 'Evandy Annex',
 'Evandy Hostel',
 'Flint Exclusiv Annex',
 'Flint Hostel',
 'Frontline Inn',
 'Franco',
 'Gaza Hostel',
 'Georgia Hostel',
 'Ghana Hostels (Gaza)',
 'Glory Be To God Annex',
 'Glory Hostel',
 'Goergia Hostel',
 'Gusss Hostel',
 'Hall 7',
 'Indece Hall',
 'Jalex Annex',
 'Jalex Hostel',
 'Jecado',
 'Lianda Hostel',
 'Liendaville Hostel',
 'Lion Of Judah Hostel',
 'Long Island',
 'Mama Thess',
 'Mass',
 'Melinda Hostel',
 'Naasie Hostel',
 'Nana Adomah Hostel',
 'New Brunei',
 'No Weapon',
 'Nsroma Hostel',
 'Pentagon Hostel',
 'Platinumville',
 'Princeville Hostel',
 'R. P. Baffour Complex Hostel',
 'Rising Sun',
 'Royal Gate Hostel',
 'Showers Hostel, Bomso',
 'Shalom',
 'Splendor Hostel',
 'SRC Hostel',
 'St Peters',
 'Suncity',
 'Ultimate Hostel',
 'Victory Towers',
 'Wagyingo Hostel',
 'West End Hostel',
 'Whitpam A Hostel',
 'White House',
 'Zoro 1'
]

# %%
# Manually Labelled the geospatial coordinates with Google Maps
unique_hostels = [
 ('Adombi', 6.672359966103428, -1.5608471216898865),
 ('Showers Hostel, Bomso',6.684435955538569, -1.5767901529327308),
 ('Shalom',6.671611292293625, -1.5626726542206908),
 ('Splendor Hostel',6.67752706148377, -1.557545864019065),
 ('SRC Hostel',6.681185685147133, -1.5716774351835605),
 ('St Peters',6.670131917690481, -1.5594340640191309),
 ('Suncity',6.688562449121462, -1.5547799640188973),
 ('Ultimate Hostel',6.684658481822585, -1.5804057860761327),
 ('Victory Towers',6.6756811055103595, -1.5624244640191036),
 ('Wagyingo Hostel', 6.67387350559082, -1.5587787928544703),
 ('West End Hostel',6.677799105416054, -1.5633333063482604),
 ('Whitpam A Hostel',6.669008893326046, -1.5621979756653033),
 ('White House', 6.6730160740910565, -1.5627376640190902),
 ('Zoro 1',6.693375126174477, -1.5586919812080817),
]

# %%
# Created a Dataset of hostels and its respective coordinates. This was later used to plot locations with QGIS
df_hostel = pd.DataFrame(unique_hostels, columns=['Hostel','Latitude', 'Longitude'])
display(df_hostel.head())
# Out:
#                Hostel  Latitude  Longitude
# 0              Adombi  6.672360  -1.560847
# 1  Adowa Ekyaa Hostel  6.684364  -1.580400
# 2       Afirim Hostel  6.673840  -1.563401
# 3         Agape Chara  6.669724  -1.562922
# 4     Anglican Hostel  6.685542  -1.552986

# %%
unnecessary_columns = ['start','end', '_uuid', '_id', '__version__',
                       '_index','_submission_time','_status','_submitted_by',
                       '_notes','_validation_status','_tags','Have you ever changed your hostel before?.1']

# %%
df = df.drop(columns=unnecessary_columns)

# %%
df.dropna(axis=1, inplace=True)
display(df)
# Out:
#      Gender  Year of Study Where are you currently staying?  \
# 0      Male              4                       Off-Campus
# 1      Male              4                       Off-Campus
# 2    Female              4                       Off-Campus
# 3      Male              4                       Off-Campus
# 4    Female              4                       Off-Campus
# ..      ...            ...                              ...
# 395  Female              1                       Off-Campus
# 396    Male              2                       Off-Campus
# 397    Male              2                       Off-Campus
# 398    Male              4                       Off-Campus
# 399    Male              2                       Off-Campus
#
#     Which do you prefer?   \
# 0       Off-campus hostel
# 1        On-campus hostel
# 2       Off-campus hostel
# 3       Off-campus hostel
# 4        On-campus hostel
# ..                    ...
# 395     Off-campus hostel
# ...

# %%
columns = df.columns

# %%
# short_names = [
#     'gender', 'year_study', 'current_stay', 'hostel_name', 'preference',
#     'pref_reasons', 'pref_afford', 'pref_proximity', 'pref_social',
#     'pref_amenities', 'pref_security', 'change_accommodation', 'satisfaction',
#     'prefer_closer', 'distance_affects_attendance', 'commute_mode',
#     'commute_walk', 'commute_bike', 'commute_bus', 'commute_taxi',
#     'proximity_focus', 'funding_source', 'changed_before', 'change_reason',
#     'change_afford', 'change_proximity', 'change_social', 'change_amenities',
#     'change_security', 'price_increase_change', 'less_pref_due_cost',
#     'amenities_list', 'amenity_water', 'amenity_electricity', 'amenity_internet',
#     'amenity_laundry', 'amenity_aircon', 'amenity_cleanbath',
#     'issues_basic_services', 'rating_overall', 'water_supply', 'electricity_supply',
#     'internet_access', 'room_cleanliness', 'bathroom_facility', 'hostel_management',
#     'study_space_conducive', 'env_collaboration', 'social_influence',
#     'roommate_relations', 'rating', 'security_measures', 'security_personnel',
#     'security_cctv', 'security_fencing', 'security_checkin', 'security_none',
#     'experienced_theft', 'security_confidence', 'focus_feeling', 'mental_health',
#     'consistent_study_routine', 'study_elsewhere', 'study_hours', 'suggestions'
# ]

# import pandas as pd

# description_df = pd.DataFrame({
#     'Short Name': short_names,
#     'Original Column': columns
# })

# %%
# Shorten column names
# GPT helped to shorten columns names

short_names = [
    'gender', 'year_study', 'current_stay','preference',
    'pref_reasons', 'pref_afford', 'pref_proximity', 'pref_social',
    'pref_amenities', 'pref_security', 'change_accommodation',
    'satisfaction', 'prefer_closer', 'distance_affects_attendance',
    'commute_mode', 'commute_walk', 'commute_bike', 'commute_bus', 'commute_taxi',
    'proximity_focus', 'funding_source', 'changed_before', 'less_pref_due_cost',
    'amenities_list', 'amenity_water', 'amenity_electricity', 'amenity_internet',
    'amenity_laundry', 'amenity_aircon', 'amenity_cleanbath', 'issues_basic_services',
    'water_supply', 'electricity_supply', 'internet_access', 'room_cleanliness',
    'bathroom_facility', 'hostel_management', 'study_space_conducive',
    'env_collaboration', 'social_influence', 'rating',
    'security_personnel', 'security_cctv', 'security_fencing',
    'security_checkin', 'security_none', 'experienced_theft', 'security_confidence',
    'focus_feeling', 'mental_health', 'consistent_study_routine', 'study_elsewhere',
    'study_hours'
]

# Create a description table
description_df = pd.DataFrame({
    'Short Name': short_names,
    'Original Column': columns
})

# %%
description_df
# Out:
#                      Short Name  \
# 0                        gender
# 1                    year_study
# 2                  current_stay
# 3                    preference
# 4                  pref_reasons
# 5                   pref_afford
# 6                pref_proximity
# 7                   pref_social
# 8                pref_amenities
# 9                 pref_security
# 10         change_accommodation
# 11                 satisfaction
# 12                prefer_closer
# 13  distance_affects_attendance
# 14                 commute_mode
# 15                 commute_walk
# 16                 commute_bike
# 17                  commute_bus
# 18                 commute_taxi
# 19              proximity_focus
# 20               funding_source
# 21               changed_before
# 22           less_pref_due_cost
# 23               amenities_list
# 24                amenity_water
# 25          amenity_electricity
# 26             amenity_internet
# 27              amenity_laundry
# ...

# %%
# Create mapping dictionary
col_mapping = dict(zip(columns, short_names))

# Rename columns
df = df.rename(columns=col_mapping)

# %%
df.head()
# Out:
#    gender  year_study current_stay         preference  \
# 0    Male           4   Off-Campus  Off-campus hostel
# 1    Male           4   Off-Campus   On-campus hostel
# 2  Female           4   Off-Campus  Off-campus hostel
# 3    Male           4   Off-Campus  Off-campus hostel
# 4  Female           4   Off-Campus   On-campus hostel
#
#                                                                                                              pref_reasons  \
# 0                                 Affordability Proximity to lecture halls Availability of amenities (Wi-Fi, water, etc.)
# 1                Proximity to lecture halls Access to social life Availability of amenities (Wi-Fi, water, etc.) Security
# 2                                                                                     Affordability Access to social life
# 3  Affordability Proximity to lecture halls Access to social life Availability of amenities (Wi-Fi, water, etc.) Security
# ...

# %%
# df.drop(columns=['amenities_list','commute_mode','pref_reasons']).to_csv('Cleaned_hostel_dataset.csv', index=False)
df.to_csv('Cleaned_hostel_dataset.csv', index=False)
